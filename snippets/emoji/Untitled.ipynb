# %%
with open('raw-emojis.txt') as f:
    lines = f.readlines()
    for line in lines:
#         print line
        line = line.replace("\n", "")
        words = line.split(" ")
        emoji = words[0]
#         print "emoji is "+emoji
        words.remove(emoji)
        description = " ".join(words)
#         print "emoji: "+emoji+", descr: "+description
        print '"Insert '+line+'": { "prefix": "emoji-'+description+' '+emoji+'", "body": "'+emoji+'", "description": "Insert '+line+'" }, '
# Out:
# "Insert ☠ Skull and Crossbones": { "prefix": "emoji-Skull and Crossbones ☠", "body": "☠", "description": "Insert ☠ Skull and Crossbones" },
# "Insert 🛀 Person Taking Bath": { "prefix": "emoji-Person Taking Bath 🛀", "body": "🛀", "description": "Insert 🛀 Person Taking Bath" },
# "Insert 🛌 Person in Bed": { "prefix": "emoji-Person in Bed 🛌", "body": "🛌", "description": "Insert 🛌 Person in Bed" },
# "Insert 💌 Love Letter": { "prefix": "emoji-Love Letter 💌", "body": "💌", "description": "Insert 💌 Love Letter" },
# "Insert 💣 Bomb": { "prefix": "emoji-Bomb 💣", "body": "💣", "description": "Insert 💣 Bomb" },
# "Insert 🕳 Hole": { "prefix": "emoji-Hole 🕳", "body": "🕳", "description": "Insert 🕳 Hole" },
# "Insert 🛍 Shopping Bags": { "prefix": "emoji-Shopping Bags 🛍", "body": "🛍", "description": "Insert 🛍 Shopping Bags" },
# "Insert 📿 Prayer Beads": { "prefix": "emoji-Prayer Beads 📿", "body": "📿", "description": "Insert 📿 Prayer Beads" },
# ...
